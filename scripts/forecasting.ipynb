# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json

with open('/content/drive/MyDrive/mit-bih/beat_symbols.json', encoding='utf-8') as file:
    beat_syms = json.load(file)

# %%
import pandas as pd

for k in beat_syms.keys():
    print(f'k: {k}')
    print(pd.Series(beat_syms[k]).value_counts(), end='\n\n')
# Out:
# k: 100
# N    2239
# S      33
# Q       1
# V       1
# Name: count, dtype: int64
#
# k: 101
# N    1860
# Q      11
# S       3
# Name: count, dtype: int64
#
# k: 103
# N    2082
# Q       7
# S       2
# Name: count, dtype: int64
#
# k: 105
# N    2526
# Q     124
# V      41
# Name: count, dtype: int64
#
# k: 106
# N    1507
# V     520
# Q      71
# Name: count, dtype: int64
#
# k: 107
# Q    2081
# V      59
# Name: count, dtype: int64
#
# k: 108
# N    1740
# Q      61
# V      17
# S       4
# F       2
# Name: count, dtype: int64
#
# k: 109
# N    2492
# V      38
# Q       3
# F       2
# Name: count, dtype: int64
#
# k: 111
# N    2123
# Q       9
# V       1
# Name: count, dtype: int64
#
# k: 112
# N    2537
# Q      11
# S       2
# Name: count, dtype: int64
#
# k: 113
# N    1789
# S       6
# Q       1
# Name: count, dtype: int64
#
# k: 114
# N    1820
# V      43
# S      12
# Q      11
# F       4
# Name: count, dtype: int64
#
# k: 115
# N    1953
# Q       9
# Name: count, dtype: int64
#
# k: 116
# N    2302
# V     109
# Q       9
# S       1
# Name: count, dtype: int64
#
# k: 117
# N    1534
# Q       4
# S       1
# Name: count, dtype: int64
#
# k: 118
# N    2166
# S      96
# Q      23
# V      16
# Name: count, dtype: int64
#
# k: 119
# N    1543
# V     444
# Q     107
# Name: count, dtype: int64
#
# k: 121
# N    1861
# Q      13
# S       1
# V       1
# Name: count, dtype: int64
#
# k: 122
# N    2476
# Q       3
# Name: count, dtype: int64
#
# k: 123
# N    1515
# V       3
# Q       1
# Name: count, dtype: int64
#
# k: 124
# N    1536
# V      47
# S      31
# Q      15
# F       5
# Name: count, dtype: int64
#
# k: 200
# N    1743
# V     826
# Q     191
# S      30
# F       2
# Name: count, dtype: int64
#
# k: 201
# N    1635
# V     198
# S     128
# Q      76
# F       2
# Name: count, dtype: int64
#
# k: 202
# N    2061
# S      55
# V      19
# Q      10
# F       1
# Name: count, dtype: int64
#
# k: 203
# N    2529
# V     444
# Q     132
# S       2
# F       1
# Name: count, dtype: int64
#
# k: 205
# N    2571
# V      71
# Q      16
# F      11
# S       3
# Name: count, dtype: int64
#
# k: 207
# N    1543
# Q     525
# V     210
# S     107
# Name: count, dtype: int64
#
# k: 208
# N    1586
# V     992
# F     373
# Q      87
# S       2
# Name: count, dtype: int64
#
# k: 209
# N    2621
# S     383
# Q      47
# V       1
# Name: count, dtype: int64
#
# k: 210
# N    2423
# V     195
# Q      35
# S      22
# F      10
# Name: count, dtype: int64
#
# k: 212
# N    2748
# Q      15
# Name: count, dtype: int64
#
# k: 213
# N    2641
# F     362
# V     220
# Q      43
# S      28
# Name: count, dtype: int64
#
# k: 214
# N    2003
# V     256
# Q      37
# F       1
# Name: count, dtype: int64
#
# k: 215
# N    3195
# V     164
# Q      37
# S       3
# F       1
# Name: count, dtype: int64
#
# k: 217
# Q    1874
# N     244
# V     162
# Name: count, dtype: int64
#
# k: 219
# N    2082
# Q     158
# V      64
# S       7
# F       1
# Name: count, dtype: int64
#
# k: 220
# N    1954
# S      94
# Q      21
# Name: count, dtype: int64
#
# k: 221
# N    2031
# V     396
# Q      35
# Name: count, dtype: int64
#
# k: 222
# N    2274
# S     209
# Q     151
# Name: count, dtype: int64
#
# k: 223
# N    2045
# V     473
# S      73
# Q      38
# F      14
# Name: count, dtype: int64
#
# k: 228
# N    1688
# V     362
# Q      88
# S       3
# Name: count, dtype: int64
#
# k: 230
# N    2255
# Q     210
# V       1
# Name: count, dtype: int64
#
# k: 231
# N    1568
# Q     440
# V       2
# S       1
# Name: count, dtype: int64
#
# k: 232
# S    1382
# N     398
# Q      36
# Name: count, dtype: int64
#
# k: 233
# N    2230
# V     831
# Q      73
# F      11
# S       7
# Name: count, dtype: int64
#
# k: 234
# N    2700
# S      50
# Q      11
# V       3
# Name: count, dtype: int64

# %%
import torch
import torch.nn as nn


def beat_to_idx(symbols: list[str]) -> list[int]:
    aami_mapping = {
        # class N
        'N': 0, 'L': 0, 'R': 0, 'e': 0, 'j': 0,
        # class S
        'S': 1, 'A': 1, 'a': 1, 'J': 1,
        # class V
        'V': 2, 'E': 2,
        # class F
        'F': 3
    }
    return [aami_mapping.get(sym, 4) for sym in symbols]


def calc_weights(seq: list[int]):
    N = len(seq)
    counts = pd.Series(seq).value_counts()
    K = len(counts)
    weights = N / (K * counts)
    weights = torch.tensor([weights.get(i, 0) for i in range(CharTransformer.V)], dtype=torch.float)
    return weights / weights.mean()


class CharTransformer(nn.Module):
    SEQ_LEN: int = 200  # context window
    H: int = 20  # horizon
    V: int = 5  # vocab size

    def __init__(
            self,
            d_model: int = 64,
            nhead: int = 4,
            num_layers: int = 2
    ):
        super().__init__()

        self.embed = nn.Embedding(self.V, d_model)
        self.pos = nn.Embedding(self.SEQ_LEN, d_model)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=128,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers)

        self.head = nn.Linear(d_model, self.H * self.V)

    def forward(self, x):
        B, T = x.shape
        pos = torch.arange(T, device=x.device)
        out = self.embed(x) + self.pos(pos)
        out = self.transformer(out)

        last = out[:, -1, :]
        logits = self.head(last)
        logits = logits.view(B, self.H, -1)
        return logits

# %%
data_id = '208'
seq = beat_to_idx(beat_syms[data_id])
print(pd.Series(seq).value_counts(), end='\n\n')
# Out:
# 0    1586
# 2     992
# 3     373
# 4      87
# 1       2
# Name: count, dtype: int64

# %%
SEQ_LEN = CharTransformer.SEQ_LEN
H = CharTransformer.H
V = CharTransformer.V

# %%
train_seq = seq[:-H]
test_seq = seq[-H:]

# %%
X, y = [], []
N = len(train_seq)
for i in range(N - SEQ_LEN - H + 1):
    X.append(train_seq[i: i + SEQ_LEN])
    y.append(train_seq[i + SEQ_LEN: i + SEQ_LEN + H])

# %%
X = torch.tensor(X)
y = torch.tensor(y)

# %%
print(f"Training samples: {len(X)} | context={SEQ_LEN} | horizon H={H}")
# Out:
# Training samples: 2801 | context=200 | horizon H=20

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CharTransformer().to(device)

# %%
from torch.utils.data import TensorDataset, DataLoader

dataset = TensorDataset(X, y)
loader = DataLoader(
    dataset,
    batch_size=64,
    shuffle=True,
    pin_memory=True if device.type == 'cuda' else False,
    num_workers=2
)

# %%
from torch.optim.lr_scheduler import OneCycleLR
from torch.nn.utils import clip_grad_norm_

EPOCHS = 100
opt = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-2)
scheduler = OneCycleLR(
    opt,
    max_lr=3e-3,
    epochs=EPOCHS,
    steps_per_epoch=len(loader)
)

weights = calc_weights(train_seq).to(device)
loss_fn = nn.CrossEntropyLoss(weight=weights)

for epoch in range(EPOCHS):
    model.train()
    epoch_loss = 0.0

    for batch_X, batch_y in loader:
        batch_X = batch_X.to(device, non_blocking=True)
        batch_y = batch_y.to(device, non_blocking=True)

        logits = model(batch_X)

        loss = loss_fn(logits.reshape(-1, V), batch_y.reshape(-1))

        opt.zero_grad()
        loss.backward()

        clip_grad_norm_(model.parameters(), max_norm=1.0)

        opt.step()
        scheduler.step()

        epoch_loss += loss.item()

    print(f"Epoch {epoch + 1}, Loss: {epoch_loss / len(loader):.4f}")
# Out:
# Epoch 1, Loss: 1.6895
# Epoch 2, Loss: 1.6236
# Epoch 3, Loss: 1.5937
# Epoch 4, Loss: 1.5914
# Epoch 5, Loss: 1.5514
# Epoch 6, Loss: 1.5303
# Epoch 7, Loss: 1.5358
# Epoch 8, Loss: 1.5210
# Epoch 9, Loss: 1.4756
# Epoch 10, Loss: 1.4806
# Epoch 11, Loss: 1.4550
# Epoch 12, Loss: 1.4055
# Epoch 13, Loss: 1.4296
# Epoch 14, Loss: 1.3270
# Epoch 15, Loss: 1.3213
# Epoch 16, Loss: 1.3183
# Epoch 17, Loss: 1.2192
# Epoch 18, Loss: 1.1787
# Epoch 19, Loss: 1.1457
# Epoch 20, Loss: 1.0750
# Epoch 21, Loss: 1.0608
# Epoch 22, Loss: 1.0755
# Epoch 23, Loss: 1.0045
# Epoch 24, Loss: 1.0433
# Epoch 25, Loss: 1.0290
# Epoch 26, Loss: 1.0240
# Epoch 27, Loss: 1.0072
# Epoch 28, Loss: 0.9868
# Epoch 29, Loss: 0.9842
# Epoch 30, Loss: 0.9928
# Epoch 31, Loss: 0.9587
# Epoch 32, Loss: 0.9555
# Epoch 33, Loss: 0.9495
# Epoch 34, Loss: 0.9723
# Epoch 35, Loss: 0.9389
# Epoch 36, Loss: 0.9466
# Epoch 37, Loss: 0.9249
# Epoch 38, Loss: 0.9081
# Epoch 39, Loss: 0.9065
# Epoch 40, Loss: 0.9011
# Epoch 41, Loss: 0.8798
# Epoch 42, Loss: 0.9088
# Epoch 43, Loss: 0.8943
# Epoch 44, Loss: 0.8621
# Epoch 45, Loss: 0.8613
# Epoch 46, Loss: 0.8500
# Epoch 47, Loss: 0.8558
# Epoch 48, Loss: 0.8446
# Epoch 49, Loss: 0.8316
# Epoch 50, Loss: 0.8260
# Epoch 51, Loss: 0.8057
# Epoch 52, Loss: 0.7844
# Epoch 53, Loss: 0.7775
# Epoch 54, Loss: 0.7741
# Epoch 55, Loss: 0.7674
# Epoch 56, Loss: 0.7569
# Epoch 57, Loss: 0.7466
# Epoch 58, Loss: 0.7245
# Epoch 59, Loss: 0.7310
# Epoch 60, Loss: 0.7159
# Epoch 61, Loss: 0.7023
# Epoch 62, Loss: 0.6927
# Epoch 63, Loss: 0.6949
# Epoch 64, Loss: 0.6844
# Epoch 65, Loss: 0.6634
# Epoch 66, Loss: 0.6501
# Epoch 67, Loss: 0.6606
# Epoch 68, Loss: 0.6305
# Epoch 69, Loss: 0.6359
# Epoch 70, Loss: 0.6301
# Epoch 71, Loss: 0.6201
# Epoch 72, Loss: 0.6090
# Epoch 73, Loss: 0.6093
# Epoch 74, Loss: 0.5907
# Epoch 75, Loss: 0.5898
# Epoch 76, Loss: 0.5857
# Epoch 77, Loss: 0.5690
# Epoch 78, Loss: 0.5610
# Epoch 79, Loss: 0.5601
# Epoch 80, Loss: 0.5644
# Epoch 81, Loss: 0.5497
# Epoch 82, Loss: 0.5606
# Epoch 83, Loss: 0.5496
# Epoch 84, Loss: 0.5437
# Epoch 85, Loss: 0.5382
# Epoch 86, Loss: 0.5433
# Epoch 87, Loss: 0.5280
# Epoch 88, Loss: 0.5296
# Epoch 89, Loss: 0.5250
# Epoch 90, Loss: 0.5264
# Epoch 91, Loss: 0.5240
# Epoch 92, Loss: 0.5269
# Epoch 93, Loss: 0.5261
# Epoch 94, Loss: 0.5263
# Epoch 95, Loss: 0.5229
# Epoch 96, Loss: 0.5336
# Epoch 97, Loss: 0.5183
# Epoch 98, Loss: 0.5272
# Epoch 99, Loss: 0.5236
# Epoch 100, Loss: 0.5334

# %%
model.eval()
# Out:
# CharTransformer(
#   (embed): Embedding(5, 64)
#   (pos): Embedding(200, 64)
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (linear1): Linear(in_features=64, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=128, out_features=64, bias=True)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (head): Linear(in_features=64, out_features=100, bias=True)
# )

# %%
context = torch.tensor([train_seq[-SEQ_LEN:]], device=device)
with torch.no_grad():
    logits = model(context)
    pred_idx = logits.argmax(dim=-1).squeeze(0)

# %%
print("Forecast:")
print(pred_idx)
print("Actual:")
test_seq = torch.tensor(test_seq, device=device)
print(test_seq)
# Out:
# Forecast:
# tensor([2, 2, 0, 2, 2, 0, 2, 2, 0, 2, 2, 0, 2, 2, 0, 2, 2, 0, 2, 2],
#        device='cuda:0')
# Actual:
# tensor([2, 0, 0, 2, 0, 0, 2, 4, 0, 3, 2, 0, 2, 0, 3, 2, 0, 2, 0, 0],
#        device='cuda:0')
# /tmp/ipykernel_1252/3357542057.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_seq = torch.tensor(test_seq, device=device)
